# %% [markdown]
# # SUMMER ANALYTICS 2022

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2022! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
# To create a Pandas Dataframe using the imported data
import pandas as pd
Data = pd.read_csv('/content/SA2022_W1_Pokemon.csv')
Data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
Data.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
Data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
Data.drop(columns=['#'],inplace=True)

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
Data.set_index('Name',inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
Data['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
Data['Type 1'].fillna('',inplace=True)
Data['Type 2'].fillna('', inplace=True)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
Data['abilities'] = Data['Type 1'] + "+" + Data['Type 2']

# %%
Data
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire            309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
# ...

# %%
Data[Data['abilities']=='Psychic+Flying']
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary       abilities
# Name
# Natu         70           2      False  Psychic+Flying
# Xatu         95           2      False  Psychic+Flying
# Lugia       110           2       True  Psychic+Flying
# Woobat       72           5      False  Psychic+Flying
# Swoobat     114           5      False  Psychic+Flying
# Sigilyph     97           5      False  Psychic+Flying

# %%
Data[Data['abilities']=='Psychic+Flying'].shape[0]
# Out:
# 6

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
names = Data.index
temp = list(names.str.find('Mega'))

# %%
temp[2]==-1
# Out:
# True

# %%
for i in range(0,len(temp)):
  if temp[i]==-1:
    temp[i]= False
  else:
    temp[i]=True

# %%
Data_Mega = Data[temp]
Data_Mega
# Out:
#                              Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# VenusaurMega Venusaur         Grass    Poison    625   80     100      123
# CharizardMega Charizard X      Fire    Dragon    634   78     130      111
# CharizardMega Charizard Y      Fire    Flying    634   78     104       78
# BlastoiseMega Blastoise       Water              630   79     103      120
# BeedrillMega Beedrill           Bug    Poison    495   65     150       40
# PidgeotMega Pidgeot          Normal    Flying    579   83      80       80
# AlakazamMega Alakazam       Psychic              590   55      50       65
# SlowbroMega Slowbro           Water   Psychic    590   95      75      180
# GengarMega Gengar             Ghost    Poison    600   60      65       80
# KangaskhanMega Kangaskhan    Normal              590  105     125      100
# PinsirMega Pinsir               Bug    Flying    600   65     155      120
# ...

# %%
Data_Mega.index.unique().size
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
Data['Sp. Def'].std()
# Out:
# 27.82891579711745

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
Data['Legendary'].sum()/Data.shape[0]*100
# Out:
# 8.125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
Data[(Data['Defense'] == Data['Defense'].max()).values]
# Out:
#                     Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# Shuckle                Bug    Rock    505  20      10      230       10
# AggronMega Aggron    Steel            630  70     140      230       60
#
#                      Sp. Def  Speed  Generation  Legendary     abilities  \
# Name
# SteelixMega Steelix       95     30           2      False  Steel+Ground
# Shuckle                  230      5           2      False      Bug+Rock
# AggronMega Aggron         80     50           3      False        Steel+
#
#                      Combine_Atk_SpAtk
# Name
# SteelixMega Steelix                180
# Shuckle                             20
# AggronMega Aggron                  200

# %%
Data['Sp. Def'].max()
# Out:
# 230

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here
# Data[Data['Sp. Atk'] == Data['Sp. Atk'].max()]
names = Data['abilities']
temp = list(names.str.find('Poison'))

# %%
for i in range(0,len(temp)):
  if temp[i]==-1:
    temp[i]= False
  else:
    temp[i]=True

# %%
qw = Data[temp].copy()
qw.sort_values(by='Attack',ascending=False)
# Out:
#                        Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# BeedrillMega Beedrill     Bug    Poison    495   65     150       40       15
# Toxicroak              Poison  Fighting    490   83     106       65       86
# Muk                    Poison              500  105     105       75       65
# Victreebel              Grass    Poison    490   80     105       65      100
# Nidoking               Poison    Ground    505   81     102       77       85
# ...                       ...       ...    ...  ...     ...      ...      ...
# Tentacool               Water    Poison    335   40      40       35       50
# Gastly                  Ghost    Poison    310   30      35       30      100
# Weedle                    Bug    Poison    195   40      35       30       20
# Budew                   Grass    Poison    280   40      30       35       50
# Kakuna                    Bug    Poison    205   45      25       50       25
#
# ...

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here
Data['Generation'].hist()

# %%
#your code here
Data[  (Data['Type 1']=='Psychic').values & (Data['Type 2']=='Flying').values  ]
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary       abilities
# Name
# Natu         70           2      False  Psychic+Flying
# Xatu         95           2      False  Psychic+Flying
# Lugia       110           2       True  Psychic+Flying
# Woobat       72           5      False  Psychic+Flying
# Swoobat     114           5      False  Psychic+Flying
# Sigilyph     97           5      False  Psychic+Flying

# %%
import plotly.express as px
df = px.data.tips()
fig = px.histogram(Data, x="Type 2")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#your code here
Data[ Data['Legendary'].values ]['Generation'].hist()

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
Data[ (Data['Generation'] == 4).values & np.invert(Data['Legendary']).values & ( (Data['Type 2']=='Ghost').values | (Data['Type 2']=='Ghost').values ) ].sort_values('Speed',ascending=False)
# Out:
#             Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Froslass       Ice  Ghost    480  70      80       70       80       70
# Rotom     Electric  Ghost    440  50      50       77       95       77
#
#           Speed  Generation  Legendary       abilities
# Name
# Froslass    110           4      False       Ice+Ghost
# Rotom        91           4      False  Electric+Ghost

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
charizard = Data[ Data.index=='Charizard' ]
charizard
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Charizard   Fire  Flying    534  78      84       78      109       85    100
#
#            Generation  Legendary    abilities
# Name
# Charizard           1      False  Fire+Flying

# %%
Data[ (np.invert(Data['Legendary']).values) & (Data['Sp. Def']>charizard['Sp. Def'].values[0]).values & (Data['Sp. Atk']<charizard['Sp. Atk'].values[0]).values ].shape[0]
# Out:
# 121

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, here are some bonus questions that you can try to further deepen your understanding of the topic!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here
Data['Combine_Atk_SpAtk'] = Data['Attack']+Data['Sp. Atk']
Data.sort_values('Combine_Atk_SpAtk',ascending=False)
# Out:
#                         Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# DeoxysAttack Forme     Psychic              600   50     180       20
# RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# MewtwoMega Mewtwo X    Psychic  Fighting    780  106     190      100
# MewtwoMega Mewtwo Y    Psychic              780  106     150       70
# KyogrePrimal Kyogre      Water              770  100     150       90
# ...                        ...       ...    ...  ...     ...      ...
# Marill                   Water     Fairy    250   70      20       50
# Feebas                   Water              200   20      15       20
# Magikarp                 Water              200   20      10       55
# Shuckle                    Bug      Rock    505   20      10      230
# Happiny                 Normal              220  100       5        5
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# Name
# ...

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here
Data[ Data['Legendary'].values ]

# Not able understand the question
# Out:
#                        Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Articuno                  Ice    Flying    580   90      85      100       95
# Zapdos               Electric    Flying    580   90      90       85      125
# Moltres                  Fire    Flying    580   90     100       90      125
# Mewtwo                Psychic              680  106     110       90      154
# MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100      154
# ...                       ...       ...    ...  ...     ...      ...      ...
# Diancie                  Rock     Fairy    600   50     100      150      100
# DiancieMega Diancie      Rock     Fairy    700   50     160      110      160
# HoopaHoopa Confined   Psychic     Ghost    600   80     110       60      150
# HoopaHoopa Unbound    Psychic      Dark    680   80     160       60      170
# Volcanion                Fire     Water    600   80     110      120      130
#
# ...

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here
temp = Data[ ( (Data['Generation']==6).values & Data['Legendary'].values ) ]
temp.sort_values('HP') # Weakest ( assuming weak in terms of HP )
# Out:
#                       Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Diancie                 Rock   Fairy    600   50     100      150      100
# DiancieMega Diancie     Rock   Fairy    700   50     160      110      160
# HoopaHoopa Confined  Psychic   Ghost    600   80     110       60      150
# HoopaHoopa Unbound   Psychic    Dark    680   80     160       60      170
# Volcanion               Fire   Water    600   80     110      120      130
# Zygarde50% Forme      Dragon  Ground    600  108     100      121       81
# Xerneas                Fairy            680  126     131       95      131
# Yveltal                 Dark  Flying    680  126     131       95      131
#
#                      Sp. Def  Speed  Generation  Legendary      abilities  \
# Name
# Diancie                  150     50           6       True     Rock+Fairy
# DiancieMega Diancie      110    110           6       True     Rock+Fairy
# ...

# %%
Data[ ( (Data['Generation']==3).values & (np.invert(Data['Legendary'])).values & (Data['HP']>50)).values ].shape[0]
# Out:
# 95

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
Data.sort_values('Speed')['Speed'].unique()[2] # Speed of 3rd slowest
# Out:
# 15

# %%
#your code here
Data[ Data['Speed']==15 ]
# Out:
#             Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Slowpoke     Water  Psychic    315  90      65       65       40       40
# Cleffa       Fairy             218  50      25       28       45       55
# Igglybuff   Normal    Fairy    210  90      30       15       40       20
# Wooper       Water   Ground    210  55      45       45       25       25
# Pineco         Bug             290  50      65       90       35       35
# Silcoon        Bug             205  50      35       55       25       25
# Cascoon        Bug             205  50      35       55       25       25
# Roggenrola    Rock             280  55      75       85       25       25
# Foongus      Grass   Poison    294  69      55       45       55       55
#
#             Speed  Generation  Legendary      abilities  Combine_Atk_SpAtk
# Name
# Slowpoke       15           1      False  Water+Psychic                105
# ...

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
Data.groupby(by='abilities').agg(np.mean).sort_values('HP',ascending=False)
# Out:
#                       Total          HP      Attack     Defense  Sp. Atk  \
# abilities
# Ghost+Dragon     680.000000  150.000000  110.000000  110.000000    110.0
# Dragon+Ice       686.666667  125.000000  140.000000   93.333333    140.0
# Ghost+Flying     423.000000  120.000000   65.000000   39.000000     75.0
# Ground+Steel     508.000000  110.000000  135.000000   60.000000     50.0
# Ground+Electric  471.000000  109.000000   66.000000   84.000000     81.0
# ...                     ...         ...         ...         ...      ...
# Bug+Ground       345.000000   45.500000   62.000000   97.500000     44.5
# Psychic+Fairy    397.000000   43.666667   46.666667   50.000000     95.0
# Bug+Water        269.000000   40.000000   30.000000   32.000000     50.0
# Poison+Bug       330.000000   40.000000   50.000000   90.000000     30.0
# Bug+Ghost        236.000000    1.000000   90.000000   45.000000     30.0
#
#                     Sp. Def  Speed  Generation  Legendary  Combine_Atk_SpAtk
# ...
